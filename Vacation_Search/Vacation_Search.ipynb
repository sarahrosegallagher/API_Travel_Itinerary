# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
import sys
sys.path.append("..")
from config import gkey

# Configure gmaps API key
gmaps.configure(api_key=gkey)

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("../Weather_Database/WeatherPy_Database.csv")
city_data_df
# Out:
#      City ID             City Country      Lat       Lng  Max Temp  Humidity  \
# 0          0         Meulaboh      ID   4.1363   96.1285     76.66        87
# 1          1     Punta Arenas      CL -53.1500  -70.9167     44.71        87
# 2          2        Pemberton      CA  50.3164 -122.8027     53.29        97
# 3          3        Hithadhoo      MV  -0.6000   73.0833     81.16        65
# 4          4           Torbay      CA  47.6666  -52.7314     43.57        83
# ..       ...              ...     ...      ...       ...       ...       ...
# 691      691      Garden City      US  42.3256  -83.3310     32.88        38
# 692      692        Zhanaozen      KZ  43.3000   52.8000     29.98        56
# 693      693         Westport      US  41.1415  -73.3579     30.33        32
# 694      694  Puerto Ayacucho      VE   5.6639  -67.6236     75.83        94
# 695      695        El Jicaro      GT  14.9167  -89.9000     90.81        44
#
#      Cloudiness  Wind Speed       Description
# 0            22        3.60        few clouds
# 1            75        9.22       shower rain
# 2            96        2.21   overcast clouds
# 3            58        6.22     broken clouds
# 4            75       10.36     broken clouds
# ..          ...         ...               ...
# 691          40       13.80  scattered clouds
# 692          28       11.86  scattered clouds
# 693          40       18.41  scattered clouds
# 694         100        4.79        light rain
# 695          91        7.40   overcast clouds
#
# [696 rows x 10 columns]

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 
min_temp = float(input("What is the minimum temperature you would like for your trip?"))

max_temp = float(input("What is the maximum temperature you would like for your trip?"))

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
preferred_city_data_df = city_data_df.loc[(city_data_df["Max Temp"]<= max_temp) &
                    (city_data_df["Max Temp"]>= min_temp)]

preferred_city_data_df
# Out:
#      City ID             City Country      Lat       Lng  Max Temp  Humidity  \
# 1          1     Punta Arenas      CL -53.1500  -70.9167     44.71        87
# 2          2        Pemberton      CA  50.3164 -122.8027     53.29        97
# 4          4           Torbay      CA  47.6666  -52.7314     43.57        83
# 9          9           Nemuro      JP  43.3236  145.5750     33.49        80
# 15        15           Surazh      RU  53.0175   32.3918     45.46        61
# ..       ...              ...     ...      ...       ...       ...       ...
# 685      685  Port Hawkesbury      CA  45.6169  -61.3485     36.59        98
# 686      686        Mingguang      CN  32.7802  117.9638     45.91        88
# 687      687         Zhongshu      CN  24.5167  103.7667     54.39        92
# 691      691      Garden City      US  42.3256  -83.3310     32.88        38
# 693      693         Westport      US  41.1415  -73.3579     30.33        32
#
#      Cloudiness  Wind Speed       Description
# 1            75        9.22       shower rain
# 2            96        2.21   overcast clouds
# 4            75       10.36     broken clouds
# 9             7       12.03         clear sky
# 15           62       20.02     broken clouds
# ..          ...         ...               ...
# 685         100        4.61        light rain
# 686           0       11.56         clear sky
# 687          99        4.12   overcast clouds
# 691          40       13.80  scattered clouds
# 693          40       18.41  scattered clouds
#
# [147 rows x 10 columns]

# %%
# 4a. Determine if there are any empty rows.
preferred_city_data_df.count()
# Out:
# City ID        147
# City           147
# Country        147
# Lat            147
# Lng            147
# Max Temp       147
# Humidity       147
# Cloudiness     147
# Wind Speed     147
# Description    147
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
clean_df = preferred_city_data_df.dropna()

clean_df
# Out:
#      City ID             City Country      Lat       Lng  Max Temp  Humidity  \
# 1          1     Punta Arenas      CL -53.1500  -70.9167     44.71        87
# 2          2        Pemberton      CA  50.3164 -122.8027     53.29        97
# 4          4           Torbay      CA  47.6666  -52.7314     43.57        83
# 9          9           Nemuro      JP  43.3236  145.5750     33.49        80
# 15        15           Surazh      RU  53.0175   32.3918     45.46        61
# ..       ...              ...     ...      ...       ...       ...       ...
# 685      685  Port Hawkesbury      CA  45.6169  -61.3485     36.59        98
# 686      686        Mingguang      CN  32.7802  117.9638     45.91        88
# 687      687         Zhongshu      CN  24.5167  103.7667     54.39        92
# 691      691      Garden City      US  42.3256  -83.3310     32.88        38
# 693      693         Westport      US  41.1415  -73.3579     30.33        32
#
#      Cloudiness  Wind Speed       Description
# 1            75        9.22       shower rain
# 2            96        2.21   overcast clouds
# 4            75       10.36     broken clouds
# 9             7       12.03         clear sky
# 15           62       20.02     broken clouds
# ..          ...         ...               ...
# 685         100        4.61        light rain
# 686           0       11.56         clear sky
# 687          99        4.12   overcast clouds
# 691          40       13.80  scattered clouds
# 693          40       18.41  scattered clouds
#
# [147 rows x 10 columns]

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = clean_df[["City", "Country", "Max Temp", "Description", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = " "
hotel_df
# Out:
#                 City Country  Max Temp       Description      Lat       Lng  \
# 1       Punta Arenas      CL     44.71       shower rain -53.1500  -70.9167
# 2          Pemberton      CA     53.29   overcast clouds  50.3164 -122.8027
# 4             Torbay      CA     43.57     broken clouds  47.6666  -52.7314
# 9             Nemuro      JP     33.49         clear sky  43.3236  145.5750
# 15            Surazh      RU     45.46     broken clouds  53.0175   32.3918
# ..               ...     ...       ...               ...      ...       ...
# 685  Port Hawkesbury      CA     36.59        light rain  45.6169  -61.3485
# 686        Mingguang      CN     45.91         clear sky  32.7802  117.9638
# 687         Zhongshu      CN     54.39   overcast clouds  24.5167  103.7667
# 691      Garden City      US     32.88  scattered clouds  42.3256  -83.3310
# 693         Westport      US     30.33  scattered clouds  41.1415  -73.3579
#
#     Hotel Name
# 1
# 2
# 4
# 9
# 15
# ..         ...
# 685
# 686
# 687
# 691
# 693
#
# [147 rows x 7 columns]

# %%
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

params = {
# "location" : city,
"radius": 5000,
"type": "lodging",
"key": gkey }

#use iterrows

for index, row in hotel_df.iterrows():
    
    #get lat and lng from df 
    lat = row["Lat"]
    lng = row["Lng"]

    city = row["City"]

    #add location to params
    params["location"] = f"{lat},{lng}" 

    #url and api request

    print(f"Retrieving Results for Index{index}: {city} .")

    response = requests.get(base_url, params=params).json()

    #extract
    results = response["results"]

    try:
        print(f"{results[0]['name']} in {city}.")

        hotel_df.loc[index, "Hotel Name"] = results[0]["name"]
    
    except:
        print("Could not find result...skipping.")

    print()
# Out:
# Retrieving Results for Index1: Punta Arenas .
# Hotel Hain in Punta Arenas.
#
# Retrieving Results for Index2: Pemberton .
# Pemberton Valley Lodge in Pemberton.
#
# Retrieving Results for Index4: Torbay .
# Gallows Cove in Torbay.
#
# Retrieving Results for Index9: Nemuro .
# Hotel Nemuro Kaiyoutei in Nemuro.
#
# Retrieving Results for Index15: Surazh .
# Mini Hotel Surazhichi in Surazh.
#
# Retrieving Results for Index31: Komsomolskiy .
# Ikathouse in Komsomolskiy.
#
# Retrieving Results for Index32: Skibbereen .
# The West Cork Hotel in Skibbereen.
#
# Retrieving Results for Index33: Mount Gambier .
# The Commodore in Mount Gambier.
#
# Retrieving Results for Index47: Olafsvik .
# Hotel Olafsvik in Olafsvik.
#
# Retrieving Results for Index51: Haines Junction .
# Parkside Inn in Haines Junction.
#
# Retrieving Results for Index56: Isfara .
# Kottedzh in Isfara.
#
# Retrieving Results for Index57: Novomoskovsk .
# Usad'ba "Bobriki" in Novomoskovsk.
#
# Retrieving Results for Index70: College .
# Pike's Waterfront Lodge in College.
#
# Retrieving Results for Index72: Ushuaia .
# Albatross Hotel in Ushuaia.
#
# Retrieving Results for Index76: Lasa .
# Pension Feldgärtenhof in Lasa.
#
# Retrieving Results for Index85: Shiyan .
# Fenghuang Garden Holiday Hotel in Shiyan.
#
# Retrieving Results for Index100: Cochrane .
# Days Inn & Suites by Wyndham Cochrane in Cochrane.
#
# Retrieving Results for Index107: Zhaotong .
# Jingguan Home in Zhaotong.
#
# Retrieving Results for Index113: Wakkanai .
# Hyōsetsu-sō in Wakkanai.
#
# Retrieving Results for Index114: Sovetsk .
# Гостинично-развлекательный комплекс KRONUS in Sovetsk.
#
# Retrieving Results for Index115: Port Hardy .
# Airport Inn-Port Hardy in Port Hardy.
#
# Retrieving Results for Index118: Yabrud .
# صالة افراح الاندلس in Yabrud.
#
# Retrieving Results for Index121: Namie .
# いこいの村なみえ in Namie.
#
# Retrieving Results for Index132: Rafraf .
# Les Jardins de la Mer Ghar el Melh in Rafraf.
#
# Retrieving Results for Index135: Gonbad-E Qabus .
# Samin Building in Gonbad-E Qabus.
#
# Retrieving Results for Index136: Nanortalik .
# Hotel Kap Farvel in Nanortalik.
#
# Retrieving Results for Index141: Yumen .
# Could not find result...skipping.
#
# Retrieving Results for Index149: Dandong .
# Yiranju Farmstay in Dandong.
#
# Retrieving Results for Index157: Sayyan .
# ملاطف ابوحورية in Sayyan.
#
# Retrieving Results for Index159: Shimoda .
# Shimoda Tokyu Hotel in Shimoda.
#
# Retrieving Results for Index161: Khasan .
# Fangchuan Self-Driving Camp in Khasan.
#
# Retrieving Results for Index162: Mao .
# ARTIEM Capri in Mao.
#
# Retrieving Results for Index164: Pereslavl-Zalesskiy .
# Motel Navigator in Pereslavl-Zalesskiy.
#
# Retrieving Results for Index166: Lac Du Bonnet .
# Drifter's Inn in Lac Du Bonnet.
#
# Retrieving Results for Index167: Makoshyne .
# Тополиная роща на берегу in Makoshyne.
#
# Retrieving Results for Index174: Grindavik .
# Northern Light Inn & Max's Restaurant in Grindavik.
#
# Retrieving Results for Index179: Kodiak .
# Best Western Kodiak Inn And Convention Center in Kodiak.
#
# Retrieving Results for Index183: Dongsheng .
# Crowne Plaza Ordos in Dongsheng.
#
# Retrieving Results for Index184: Yushu .
# Honorable Institute in Yushu.
#
# Retrieving Results for Index186: Ketchikan .
# Snow's Cove Lodge in Ketchikan.
#
# Retrieving Results for Index190: Sandwick .
# Beach House Self-Catering Accomodation in Sandwick.
#
# Retrieving Results for Index191: Yining .
# Xiushui Hotel in Yining.
#
# Retrieving Results for Index204: Hasaki .
# Inubosaki Kanko Hotel in Hasaki.
#
# Retrieving Results for Index205: Loudeac .
# Le France Hotel Restaurant in Loudeac.
#
# Retrieving Results for Index207: Halifax .
# Hotel Halifax in Halifax.
#
# Retrieving Results for Index215: Sitka .
# Westmark Sitka in Sitka.
#
# Retrieving Results for Index217: Plastun .
# Gostinitsa Rossiyanochka in Plastun.
#
# Retrieving Results for Index219: Klaksvik .
# Airbnb rooms in Klaksvik.
#
# Retrieving Results for Index222: Constantine .
# Grand Hotel Cirta in Constantine.
#
# Retrieving Results for Index226: Grua .
# Søndre Oppdalen Grendehus in Grua.
#
# Retrieving Results for Index229: Whitehorse .
# The Sternwheeler Hotel & Conference Centre in Whitehorse.
#
# Retrieving Results for Index239: Chifeng .
# Junyu Tiancheng Hotel in Chifeng.
#
# Retrieving Results for Index243: Mujiayingzi .
# Jinjiang Hotel in Mujiayingzi.
#
# Retrieving Results for Index244: Chute-Aux-Outardes .
# Camp St-Paul Gite Plein-Air in Chute-Aux-Outardes.
#
# Retrieving Results for Index247: Vestmannaeyjar .
# Glamping & Camping in Vestmannaeyjar.
#
# Retrieving Results for Index253: Chamalieres .
# Best Western Plus Hotel Literary Alexandre Vialatte in Chamalieres.
#
# Retrieving Results for Index258: Urumqi .
# Hua Ling Grand Hotel Urumqi in Urumqi.
#
# Retrieving Results for Index260: Bonavista .
# Sweet Sharons bnb in Bonavista.
#
# Retrieving Results for Index265: Velenje .
# Hotel Paka in Velenje.
#
# Retrieving Results for Index266: Fairbanks .
# Westmark Fairbanks Hotel & Conference Center in Fairbanks.
#
# Retrieving Results for Index267: Zaysan .
# Ерлан үй in Zaysan.
#
# Retrieving Results for Index269: Xining .
# Super Leisure Hotel in Xining.
#
# Retrieving Results for Index279: Prince George .
# Canadas Best Value Inn Prince George in Prince George.
#
# Retrieving Results for Index283: Ardatov .
# Avtostantsiya Ardatov in Ardatov.
#
# Retrieving Results for Index300: Prince Rupert .
# Crest Hotel in Prince Rupert.
#
# Retrieving Results for Index307: Seoul .
# 롯데호텔 서울 in Seoul.
#
# Retrieving Results for Index308: Jachymov .
# Hotel Blanik in Jachymov.
#
# Retrieving Results for Index313: Bafra .
# Sevgi Otel in Bafra.
#
# Retrieving Results for Index326: Den Helder .
# Hotel Den Helder in Den Helder.
#
# Retrieving Results for Index330: Hofn .
# Hótel Höfn in Hofn.
#
# Retrieving Results for Index337: Coihaique .
# Diego De Almagro Coyhaique in Coihaique.
#
# Retrieving Results for Index350: Vrede .
# Vrede Hotel in Vrede.
#
# Retrieving Results for Index362: Lerwick .
# The Lerwick Hotel in Lerwick.
#
# Retrieving Results for Index364: Hamilton .
# Six Acres Bed & Breakfast in Hamilton.
#
# Retrieving Results for Index366: Yichang .
# Gezhouba Hotel in Yichang.
#
# Retrieving Results for Index368: Makarska .
# Hotel Park Makarska in Makarska.
#
# Retrieving Results for Index370: Kirkuk .
# Cihad Oteli in Kirkuk.
#
# Retrieving Results for Index385: Makiyivka .
# Hotelʹno-Restorannyy Kompleks Melʹnytsa in Makiyivka.
#
# Retrieving Results for Index388: Havre-Saint-Pierre .
# Auberge Niapiskau in Havre-Saint-Pierre.
#
# Retrieving Results for Index393: Sakaiminato .
# Matsuya in Sakaiminato.
#
# Retrieving Results for Index396: Stromness .
# The Old Smokery in Stromness.
#
# Retrieving Results for Index400: Vigrestad .
# Brusand Camping in Vigrestad.
#
# Retrieving Results for Index404: Jiaojiang .
# Fangyuan Hotel in Jiaojiang.
#
# Retrieving Results for Index408: Mackenzie .
# Hilton Shop in Mackenzie.
#
# Retrieving Results for Index409: Sept-Iles .
# Comfort Inn in Sept-Iles.
#
# Retrieving Results for Index413: Terrace .
# Northern Motor Inn in Terrace.
#
# Retrieving Results for Index416: Kumla .
# Kumla Hotel in Kumla.
#
# Retrieving Results for Index426: Kuminskiy .
# Could not find result...skipping.
#
# Retrieving Results for Index431: Mantua .
# Hotel la Favorita in Mantua.
#
# Retrieving Results for Index438: Pachino .
# Il Veliero in Pachino.
#
# Retrieving Results for Index439: Foz .
# Hotel Balcón de San Bartolo in Foz.
#
# Retrieving Results for Index445: Birjand .
# Birjand Tourist Hotel in Birjand.
#
# Retrieving Results for Index456: Vieste .
# Hotel Falcone in Vieste.
#
# Retrieving Results for Index462: Port-Cartier .
# Le Q'Artier in Port-Cartier.
#
# Retrieving Results for Index469: Sterling .
# Hampton Inn & Suites Washington-Dulles International Airport in Sterling.
#
# Retrieving Results for Index474: Katsuura .
# Katsuura Hotel Mikazuki in Katsuura.
#
# Retrieving Results for Index475: Rio Gallegos .
# Hotel Santa Cruz in Rio Gallegos.
#
# Retrieving Results for Index477: Manchester .
# The Gardens Hotel in Manchester.
#
# Retrieving Results for Index489: Erenhot .
# Erenhot Rurouni Youth Hostel in Erenhot.
#
# Retrieving Results for Index490: Northam .
# Durrant House Hotel in Northam.
#
# Retrieving Results for Index494: Gornopravdinsk .
# Hostel in Gornopravdinsk.
#
# Retrieving Results for Index500: Ketrzyn .
# KOCH in Ketrzyn.
#
# Retrieving Results for Index502: Ventspils .
# Jūras brīze in Ventspils.
#
# Retrieving Results for Index505: Balkhash .
# Family in Balkhash.
#
# Retrieving Results for Index515: Valley City .
# AmericInn by Wyndham Valley City Conference Center in Valley City.
#
# Retrieving Results for Index517: Saint-Francois .
# Manoir Du Bonheur in Saint-Francois.
#
# Retrieving Results for Index522: Titisee-Neustadt .
# Hotel Treschers in Titisee-Neustadt.
#
# Retrieving Results for Index527: Fujin .
# Xilong Hotel Fujin Shop in Fujin.
#
# Retrieving Results for Index528: Dawson Creek .
# Peace Villa Motel in Dawson Creek.
#
# Retrieving Results for Index531: Aurich .
# Ringhotel Köhlers Forsthaus in Aurich.
#
# Retrieving Results for Index532: Liuhe .
# Grain Hostel in Liuhe.
#
# Retrieving Results for Index534: Hami .
# Laoyutang Resort in Hami.
#
# Retrieving Results for Index539: Kangly .
# Dom Otdykha in Kangly.
#
# Retrieving Results for Index544: Stony Plain .
# Travelodge by Wyndham Stony Plain in Stony Plain.
#
# Retrieving Results for Index547: Elena .
# Hotel Eleni Palace in Elena.
#
# Retrieving Results for Index549: Svetlogorsk .
# Hotel Svetlogorsk JBIK in Svetlogorsk.
#
# Retrieving Results for Index552: Muscatine .
# Bed Bekfast in Muscatine.
#
# Retrieving Results for Index554: Sicamous .
# Best Western Sicamous Inn in Sicamous.
#
# Retrieving Results for Index556: Truckee .
# Truckee Donner Lodge in Truckee.
#
# Retrieving Results for Index558: Raudeberg .
# Nordre Silda. in Raudeberg.
#
# Retrieving Results for Index562: Biograd Na Moru .
# Villa Maimare in Biograd Na Moru.
#
# Retrieving Results for Index568: Ravar .
# computertik in Ravar.
#
# Retrieving Results for Index574: Donskoye .
# Could not find result...skipping.
#
# Retrieving Results for Index581: Hede .
# Vienna 3 Best Hotel Sheyang Jiefang Rd in Hede.
#
# Retrieving Results for Index589: Colwyn Bay .
# Bryn Woodlands House in Colwyn Bay.
#
# Retrieving Results for Index592: Novikovo .
# Could not find result...skipping.
#
# Retrieving Results for Index593: Tawang .
# Hotel Mount View in Tawang.
#
# Retrieving Results for Index594: Paveh .
# اقامتگاه بوم‌گردی حسن ساعدی in Paveh.
#
# Retrieving Results for Index596: Jumla .
# Royal Garden Hotel in Jumla.
#
# Retrieving Results for Index599: Nantucket .
# Jared Coffin House in Nantucket.
#
# Retrieving Results for Index604: Bantry .
# The Maritime Hotel in Bantry.
#
# Retrieving Results for Index616: Klyuchi .
# Vesolaya Mayovka in Klyuchi.
#
# Retrieving Results for Index617: Kuryk .
# Gostinitsa Kuryk - Otel' Dlya Vsekh Kategoriy Kliyentov . in Kuryk.
#
# Retrieving Results for Index637: Jinxiang .
# Wolong Village in Jinxiang.
#
# Retrieving Results for Index652: Horsham .
# Springfields Hotel in Horsham.
#
# Retrieving Results for Index667: Zheleznodorozhnyy .
# Hotel Dali in Zheleznodorozhnyy.
#
# Retrieving Results for Index668: Borovskoy .
# Аренда жилья/Баня in Borovskoy.
#
# Retrieving Results for Index669: Monastyrshchina .
# Could not find result...skipping.
#
# Retrieving Results for Index674: Bayevo .
# Kulunda in Bayevo.
#
# Retrieving Results for Index677: Brigantine .
# Legacy Vacation Resorts - Brigantine Beach in Brigantine.
#
# Retrieving Results for Index678: Saint Anthony .
# Holiday Inn Express Roseville-St. Paul, an IHG Hotel in Saint Anthony.
#
# Retrieving Results for Index681: Saint-Augustin .
# Could not find result...skipping.
#
# Retrieving Results for Index685: Port Hawkesbury .
# MacKenzie House Tourist Home B&B in Port Hawkesbury.
#
# Retrieving Results for Index686: Mingguang .
# Yonghao Hotel in Mingguang.
#
# Retrieving Results for Index687: Zhongshu .
# Xintianlong Hotel in Zhongshu.
#
# Retrieving Results for Index691: Garden City .
# Big Trees Mobile Home Community in Garden City.
#
# Retrieving Results for Index693: Westport .
# The Inn at Longshore in Westport.

# %%
#error: could not find hotel for any country - what is error in code? (same error as previous activity)
#  #set up base url 
# base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# # 6a. Set parameters to search for hotels with 5000 meters.
# params = {
#     "radius": 5000,
#     "type": "lodging",
#     "key": gkey
# }

# # 6b. Iterate through the hotel DataFrame.
# for index, row in hotel_df.iterrows():
#     # 6c. Get latitude and longitude from DataFrame
#     lat = row["Lat"]
#     lng = row["Lng"]

#     city = row["City"]
    
#     print(f"Retrieving Results for Index{index}: {city} .")

#     # 6d. Set up the base URL for the Google Directions API to get JSON data.
#     response = requests.get(base_url, params=params).json()

#     # 6e. Make request and retrieve the JSON data from the search. 
    
#     # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.
#     #extract
#     results = response["results"]

#     try:
#         print(f"{results[0]['name']} in {city}.")

#         hotel_df.loc[index, "Hotel Name"] = results[0]["name"]
    
#     except:
#         print("Could not find result...skipping.")

#     print()

# %%
# 7. Drop the rows where there is no Hotel Name.
clean_hotel_df = hotel_df.dropna()

# %%
# 8a. Create the output File (CSV)
output_data_file = "WeatherPy_vacation"

# 8b. Export the City_Data into a csv
clean_hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
<dt>Weather Description</dt><dd>{Description} °F</dd>
</dl>
"""

# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map. 
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]

#figure variable (plus center and zoom)
fig = gmaps.figure(center=(30.0, 31.0), zoom_level =1.5)

#add heatlayer w variables (plus list comprehension, intensity, point radius)
heatmap_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp], dissipating=False, max_intensity=300, point_radius=4)
fig.add_layer(heatmap_layer)

#marker layer
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)


# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
